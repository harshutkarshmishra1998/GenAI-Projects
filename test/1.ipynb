# %%
import langserve
print(langserve.__file__)
from langserve import serve_chain
print("✅ serve_chain works!")
# Out:
# c:\Users\Utkarsh Mishra\AppData\Local\Programs\Python\Python311\Lib\site-packages\langserve\__init__.py
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 import langserve
#       2 print(langserve.__file__)
# ----> 3 from langserve import serve_chain
#       4 print("✅ serve_chain works!")
#
# ImportError: cannot import name 'serve_chain' from 'langserve' (c:\Users\Utkarsh Mishra\AppData\Local\Programs\Python\Python311\Lib\site-packages\langserve\__init__.py)
